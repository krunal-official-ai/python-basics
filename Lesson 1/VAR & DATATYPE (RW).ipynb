# %% [markdown]
# # Variable Names Validation

# %% [markdown]
# # In Python, we have the following rules to create a valid variable name.
# # 1) Only use letters ( a-z, A-Z ), underscore ( _ ) and numbers ( 0-9 ) are allowed to create variable names, nothing else.
# # 2) It must begin with a underscore ( _ ) or a letter.
# # 3) You can't use reserved keywords to create variables names. (entire Python keyword set (35 keywords) neatly categorized.)
# # 4) Variable name can be of any length.

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(A)
#
# NameError: name 'A' is not defined

# %%
a = 50 # int
b = 80.90 # float
C = 'SCIENCE' #char #STR

# %%
print(a)
print(b)
print(C)
print("- - - - - - - - ")
# Out:
# 50
# 80.9
# SCIENCE
# - - - - - - - -

# %%
_A = 10 # Int
b = "Aritificial Intelligence" # string
X = 40.90 # float

print(_A)

print(type(_A)) # datadype

print(type(b))

print(type(X))
# Out:
# 10
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
A,B,C,D,E = 30,40,50,"Robotics",50.90 # simulation variable"

X,Y,Z = 20,"krunal", 90.99

print(A)
print(B)
print(C)
print("********")
print(X)
print(Y)
print(Z)
# Out:
# 30
# 40
# 50
# ********
# 20
# krunal
# 90.99

# %%
# syntex : var = input(prompt) # Reading input from keyboard,

name = str(input("Enter your name:"))
Num = int(input("Enter your Nub:"))
add = str(input("Enter your Add:"))
perc = float(input("Enter your %: "))
print(perc,"%")
# Out:
# Enter your name: krunal
# Enter your Nub: 74634634
# Enter your Add: jduyfeurt
# Enter your %:  45
# 45.0 %

# %%
age = int(input("Enter your age: "))   # Converts input to an integer
height = float(input("Enter your height in meters: "))  # Converts to float

print("You are", age, "years old and", height, "meters tall.")
# Out:
# Enter your age:  21
# Enter your height in meters:  162
# You are 21 years old and 162.0 meters tall.
